# %%
import pandas as pd

# %%
df = pd.read_csv('animals.csv')

# %%
['hi' for _ in range(5)]
# Out:
# ['hi', 'hi', 'hi', 'hi', 'hi']

# %%
df = pd.concat([df for _ in range(75)]).reset_index(drop=True)

# %%
# df.to_csv('animals_large.csv', index=False)

# %%
df = pd.read_csv('countries.csv')

# %%
df = pd.concat([df for _ in range(13)]).reset_index(drop=True)

# %%
df.to_csv('countries_large.csv', index=False)
